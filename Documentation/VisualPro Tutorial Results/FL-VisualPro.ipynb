# %%
import numpy as np
from matplotlib import pyplot as plt
from fuzzylab import trimf

def SetTriangulation(x, data) :
    return trimf(x, data)

def ApplyFormula(formula, sets) :
    return 4

# %%
x = np.linspace(0, 50, 101)

y1 = SetTriangulation(x, [0, 10, 15])
y2 = SetTriangulation(x, [10, 25, 30])
y3 = SetTriangulation(x, [25, 50, 50])

plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, y3)

plt.show()
